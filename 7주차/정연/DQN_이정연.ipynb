# %% [markdown]
# ## 시니어

# %% [markdown]
# - DQN 코드 작성 (전에 성능 나왔으면, DDQN 구현)
# - 먼저 (5,5)와 같이 작은 사이즈의 환경에서 시작
# - 매직넘버 사용 지양

# %% [markdown]
# ---

# %% [markdown]
# ### 1. **작은 사이즈, 적은 지뢰 밀도** 환경에서 학습되는지 확인

# %% [markdown]
# ### 시니어용 세팅

# %%
! git clone "https://github.com/KanghwaSisters/DQN_minesweeper.git"
# Out:
# fatal: destination path 'DQN_minesweeper' already exists and is not an empty directory.

# %%
import os
os.chdir('/content/DQN_minesweeper/codes/Environment')

# %%
! python reward5.py
from reward5 import *

# %%
env = MinesweeperEnv(map_size=(5,5),
                     n_mines=5,
                     rewards={'win':1.5, 'lose':-1, 'progress':0.2, 'guess':0.3, 'no_progress' : -1},
                     dones={'win':True, 'lose':True, 'progress':False, 'guess':False, 'no_progress' : False},
                     dim2=False)
# dim2=False -> 다차원 state는 단일 차원 state에서 지뢰(-2), 까짐 여부(-1), 주변 지뢰 개수의 합을 각각의 채널로 받고, 원핫인코딩으로 값을 표현한다.

# env.state.shape -> input state (11, 5, 5)

# %% [markdown]
# ### Import

# %%
import random
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import deque

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# ### Net

# %%
class Net(nn.Module):
    def __init__(self, input_dims, n_actions, conv_units, in_channels=11):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=conv_units, kernel_size=(3,3), bias=False, padding=2)
        self.conv2 = nn.Conv2d(in_channels=conv_units, out_channels=conv_units, kernel_size=(3,3), bias=False, padding=1)
        self.conv3 = nn.Conv2d(in_channels=conv_units, out_channels=conv_units, kernel_size=(3,3), bias=False, padding=1)
        self.conv4 = nn.Conv2d(in_channels=conv_units, out_channels=conv_units, kernel_size=(3,3), bias=False, padding=1)

        self.flatten = nn.Flatten()

        fc_size = conv_units * (input_dims[-1]+2) * (input_dims[-2]+2)

        self.fc = nn.Linear(fc_size, n_actions)

    def forward(self, x):
        # conv area
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))

        x = self.flatten(x)
        # flatten area
        x = self.fc(x)

        return x

# %% [markdown]
# ### Agent

# %% [markdown]
# 0 ~ 8 : 주변 지뢰 개수
#
# -1    : 열리지 않은 타일
#
# -2    : 지뢰
# ***
#
# `env.step(action_idx)`
#
# -> return self.state, reward, done
#
# `env.state.shape`
#
# -> input state (11, 5, 5) : 5x5 판 11개
#
# `env.reset()`
#
# -> 게임 보드와 state 생성

# %%
# Hyperparameters
DISCOUNT_FACTOR = 0.8
LEARNING_RATE = 0.005

EPSILON = 0.5
EPSILON_DECAY = 0.998
EPSILON_MIN = 0.01

TARGET_UPDATE_COUNTER = 0
UPDATE_TARGET_EVERY = 10
CONV_UNITS = 32

BATCH_SIZE = 32
TRAIN_START = 500
MAX_LEN = 10000

# %%
# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class Agent(nn.Module):
    def __init__(self, env):
        super(Agent, self).__init__()

        self.epsilon = EPSILON
        self.epsilon_decay = EPSILON_DECAY
        self.epsilon_min = EPSILON_MIN

        self.target_update_counter = TARGET_UPDATE_COUNTER
        self.update_target_every = UPDATE_TARGET_EVERY

        self.train_start = TRAIN_START
        self.memory = deque(maxlen=MAX_LEN)

        self.model = Net(env.state.shape, env.total_tiles, CONV_UNITS).to(device)
        self.target_model = Net(env.state.shape, env.total_tiles, CONV_UNITS).to(device)
        self.loss = nn.MSELoss()
        self.optimizer = optim.Adam(self.model.parameters(), lr=LEARNING_RATE, eps=1e-4)
        self.scheduler = optim.lr_scheduler.CyclicLR(optimizer=self.optimizer, base_lr=0.0001, max_lr=0.1, step_size_up=10000, mode='exp_range')

        self.update_target_model()

    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def get_action(self, state):
        state = np.array(state).reshape(1, 11, env.ncols, env.nrows)
        state = torch.FloatTensor(state).to(device)

        if np.random.rand() <= EPSILON:
            action = random.randrange(env.total_tiles)
        else:
            q_value = self.model(state)
            self.q_value = q_value.detach().cpu().numpy().flatten()
            action = torch.argmax(q_value).item()

        return action

    def append_sample(self, state, action, reward, next_state, done):
        state = state
        next_state = next_state
        self.memory.append((state, action, reward, next_state, done))

    def train_model(self):
        if len(self.memory) < BATCH_SIZE:
            return

        minibatch = random.sample(self.memory, BATCH_SIZE)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        states = np.array(states)
        actions = np.array(actions)
        rewards = np.array(rewards)
        next_states = np.array(next_states)
        dones = np.array(dones)

        states = states.reshape(BATCH_SIZE, 11, env.ncols, env.nrows)
        next_states = next_states.reshape(BATCH_SIZE, 11, env.ncols, env.nrows)

        states = torch.tensor(states, dtype=torch.float32).to(device)
        actions = torch.tensor(actions, dtype=torch.long).to(device)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        next_states = torch.tensor(next_states, dtype=torch.float32).to(device)
        dones = torch.tensor(dones, dtype=torch.float32).to(device)

        pred = self.model(states)
        target_pred = self.target_model(next_states).max(1)[0].detach()

        targets = rewards + (1 - dones) * DISCOUNT_FACTOR * target_pred

        pred = pred.gather(1, actions.unsqueeze(1))
        trg = targets.unsqueeze(1)

        loss = self.loss(pred, trg)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.scheduler.step()

        self.target_update_counter += 1
        if self.target_update_counter >= self.update_target_every:
            self.target_update_counter = 0
            self.update_target_model()

# %% [markdown]
# ### Main

# %%
agent = Agent(env)

EPISODES = 3000
RENDER_PROCESS = False
RENDER_END = False

total_moves = []
scores = np.zeros(EPISODES)
length_memory = np.zeros(EPISODES)
wins = np.zeros(EPISODES)
episodes = np.zeros(EPISODES)
timesteps = np.zeros(EPISODES)
win_rates = {}

N = 100

for epi in range(EPISODES):
    done = False
    score = 0
    time_step = 0
    actions = []
    rewards = []

    env.reset()
    state = env.state
    agent.epsilon = max(agent.epsilon_min, agent.epsilon * agent.epsilon_decay)

    while not done and time_step <= 40:
        time_step += 1
        action = agent.get_action(state)

        # 선택한 행동으로 환경에서 한 타임스텝 진행
        next_state, reward, done = env.step(action)
        score += reward

        # 선택한 action(좌표) 리스트에 추가
        actions.append(env.get_coord(action))
        rewards.append(reward)

        # 메모리에 샘플 저장 및 학습
        agent.append_sample(state, action, reward, next_state, done)
        if len(agent.memory) >= agent.train_start:
            agent.train_model()

        state = next_state

    scores[epi] = score
    timesteps[epi] = time_step

    # 에피소드가 끝날 때 승리 여부를 기록
    if done and reward == env.rewards['win']:
        wins[epi] = 1
        # print(f"Episode: {epi} | Score: {score} | Timesteps: {time_step} | Epsilon: {agent.epsilon:.4f}")
        # env.render(state)

    if (epi) % N == 0:
        scores_N = np.median(scores[max(0, epi - N + 1):epi + 1])  # 마지막 N개의 점수 중간값
        win_rate = np.mean(wins[max(0, epi - N + 1):epi + 1]) * 100  # 승률
        win_rates[epi] = win_rate
        length_memory[epi] = len(agent.memory)

        print(f"Episode {epi:3d} | Timesteps: {time_step}")
        print(f"Score: {scores_N:.2f} | Win Rate: {win_rate:.2f}% | Epsilon: {agent.epsilon:.4f}\n")
        env.render(state)  # 상태 표시
        print(f"Actions taken: {actions}")
        print(f"Rewards per timestep: {rewards}")
        print("--------------------------------------------------")
# Out:
# Episode   0 | Timesteps: 3
# Score: -0.40 | Win Rate: 0.00% | Epsilon: 0.4990
# <style type="text/css">
# #T_466f0_row0_col0, #T_466f0_row0_col1, #T_466f0_row0_col2, #T_466f0_row0_col3, #T_466f0_row1_col0, #T_466f0_row1_col1, #T_466f0_row1_col2, #T_466f0_row1_col4, #T_466f0_row2_col0, #T_466f0_row2_col1, #T_466f0_row2_col2, #T_466f0_row2_col3, #T_466f0_row2_col4, #T_466f0_row3_col0, #T_466f0_row3_col1, #T_466f0_row3_col3, #T_466f0_row3_col4, #T_466f0_row4_col0, #T_466f0_row4_col1, #T_466f0_row4_col2, #T_466f0_row4_col3, #T_466f0_row4_col4 {
#   color: white;
# }
# #T_466f0_row0_col4 {
#   color: green;
# }
# #T_466f0_row1_col3 {
#   color: magenta;
# }
# #T_466f0_row3_col2 {
#   color: blue;
# }
# </style>
# <table id="T_466f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_466f0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_466f0_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_466f0_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_466f0_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_466f0_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_466f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_466f0_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_466f0_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_466f0_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_466f0_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_466f0_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_466f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_466f0_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_466f0_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_466f0_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_466f0_row1_col3" class="data row1 col3" >M</td>
#       <td id="T_466f0_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_466f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_466f0_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_466f0_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_466f0_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_466f0_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_466f0_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_466f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_466f0_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_466f0_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_466f0_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_466f0_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_466f0_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_466f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_466f0_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_466f0_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_466f0_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_466f0_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_466f0_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(3, 2), (0, 4), (1, 3)]
# Rewards per timestep: [0.3, 0.3, -1]
# --------------------------------------------------
# Episode 100 | Timesteps: 4
# Score: -1.40 | Win Rate: 1.00% | Epsilon: 0.4085
# <style type="text/css">
# #T_6fa93_row0_col0, #T_6fa93_row0_col1, #T_6fa93_row0_col2, #T_6fa93_row1_col0, #T_6fa93_row1_col1, #T_6fa93_row2_col0, #T_6fa93_row2_col1, #T_6fa93_row3_col0, #T_6fa93_row3_col1, #T_6fa93_row4_col0, #T_6fa93_row4_col1 {
#   color: slategrey;
# }
# #T_6fa93_row0_col3, #T_6fa93_row1_col2 {
#   color: blue;
# }
# #T_6fa93_row0_col4, #T_6fa93_row1_col4, #T_6fa93_row2_col3, #T_6fa93_row2_col4, #T_6fa93_row3_col3, #T_6fa93_row3_col4, #T_6fa93_row4_col4 {
#   color: white;
# }
# #T_6fa93_row1_col3, #T_6fa93_row2_col2, #T_6fa93_row4_col2 {
#   color: green;
# }
# #T_6fa93_row3_col2 {
#   color: red;
# }
# #T_6fa93_row4_col3 {
#   color: magenta;
# }
# </style>
# <table id="T_6fa93" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fa93_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6fa93_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6fa93_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_6fa93_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_6fa93_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fa93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fa93_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6fa93_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_6fa93_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6fa93_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_6fa93_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_6fa93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6fa93_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_6fa93_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_6fa93_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_6fa93_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_6fa93_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_6fa93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6fa93_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_6fa93_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_6fa93_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_6fa93_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_6fa93_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_6fa93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6fa93_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_6fa93_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_6fa93_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_6fa93_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_6fa93_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_6fa93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6fa93_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_6fa93_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_6fa93_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_6fa93_row4_col3" class="data row4 col3" >M</td>
#       <td id="T_6fa93_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(4, 0), (1, 2), (2, 0), (4, 3)]
# Rewards per timestep: [0.3, -1, -1, -1]
# --------------------------------------------------
# Episode 200 | Timesteps: 3
# Score: -0.70 | Win Rate: 0.00% | Epsilon: 0.3344
# <style type="text/css">
# #T_ec662_row0_col0, #T_ec662_row2_col3, #T_ec662_row3_col4 {
#   color: blue;
# }
# #T_ec662_row0_col1, #T_ec662_row0_col2, #T_ec662_row0_col3, #T_ec662_row1_col0, #T_ec662_row1_col1, #T_ec662_row1_col2, #T_ec662_row2_col0, #T_ec662_row2_col1, #T_ec662_row2_col2, #T_ec662_row3_col0, #T_ec662_row3_col1, #T_ec662_row3_col2, #T_ec662_row4_col0, #T_ec662_row4_col1, #T_ec662_row4_col2, #T_ec662_row4_col3, #T_ec662_row4_col4 {
#   color: white;
# }
# #T_ec662_row0_col4 {
#   color: magenta;
# }
# #T_ec662_row1_col3 {
#   color: red;
# }
# #T_ec662_row1_col4, #T_ec662_row3_col3 {
#   color: green;
# }
# #T_ec662_row2_col4 {
#   color: slategrey;
# }
# </style>
# <table id="T_ec662" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec662_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ec662_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ec662_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_ec662_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_ec662_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec662_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec662_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ec662_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_ec662_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_ec662_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_ec662_row0_col4" class="data row0 col4" >M</td>
#     </tr>
#     <tr>
#       <th id="T_ec662_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec662_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_ec662_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_ec662_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_ec662_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_ec662_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ec662_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec662_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_ec662_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_ec662_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_ec662_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_ec662_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ec662_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec662_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_ec662_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_ec662_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_ec662_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_ec662_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ec662_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec662_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_ec662_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_ec662_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_ec662_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_ec662_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(2, 4), (0, 0), (0, 4)]
# Rewards per timestep: [0.3, 0.3, -1]
# --------------------------------------------------
# Episode 300 | Timesteps: 3
# Score: -0.50 | Win Rate: 2.00% | Epsilon: 0.2737
# <style type="text/css">
# #T_c02ed_row0_col0, #T_c02ed_row0_col1 {
#   color: slategrey;
# }
# #T_c02ed_row0_col2 {
#   color: blue;
# }
# #T_c02ed_row0_col3, #T_c02ed_row0_col4, #T_c02ed_row1_col3, #T_c02ed_row1_col4, #T_c02ed_row2_col0, #T_c02ed_row2_col2, #T_c02ed_row2_col3, #T_c02ed_row2_col4, #T_c02ed_row3_col0, #T_c02ed_row3_col1, #T_c02ed_row3_col2, #T_c02ed_row3_col4, #T_c02ed_row4_col0, #T_c02ed_row4_col1, #T_c02ed_row4_col2, #T_c02ed_row4_col3, #T_c02ed_row4_col4 {
#   color: white;
# }
# #T_c02ed_row1_col0, #T_c02ed_row1_col1, #T_c02ed_row3_col3 {
#   color: green;
# }
# #T_c02ed_row1_col2 {
#   color: red;
# }
# #T_c02ed_row2_col1 {
#   color: magenta;
# }
# </style>
# <table id="T_c02ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c02ed_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c02ed_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c02ed_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c02ed_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_c02ed_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c02ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c02ed_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c02ed_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_c02ed_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_c02ed_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_c02ed_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c02ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c02ed_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c02ed_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_c02ed_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_c02ed_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_c02ed_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c02ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c02ed_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_c02ed_row2_col1" class="data row2 col1" >M</td>
#       <td id="T_c02ed_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_c02ed_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_c02ed_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c02ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c02ed_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_c02ed_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_c02ed_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_c02ed_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_c02ed_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c02ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c02ed_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_c02ed_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_c02ed_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_c02ed_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_c02ed_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(3, 3), (0, 0), (2, 1)]
# Rewards per timestep: [0.3, 0.3, -1]
# --------------------------------------------------
# Episode 400 | Timesteps: 11
# Score: -0.70 | Win Rate: 1.00% | Epsilon: 0.2240
# <style type="text/css">
# #T_c2d8b_row0_col0, #T_c2d8b_row0_col1, #T_c2d8b_row1_col0, #T_c2d8b_row1_col1, #T_c2d8b_row2_col0, #T_c2d8b_row2_col1, #T_c2d8b_row2_col3, #T_c2d8b_row2_col4, #T_c2d8b_row3_col0, #T_c2d8b_row3_col1, #T_c2d8b_row3_col2, #T_c2d8b_row3_col4, #T_c2d8b_row4_col0, #T_c2d8b_row4_col1, #T_c2d8b_row4_col3, #T_c2d8b_row4_col4 {
#   color: white;
# }
# #T_c2d8b_row0_col2, #T_c2d8b_row1_col2, #T_c2d8b_row1_col3, #T_c2d8b_row1_col4 {
#   color: blue;
# }
# #T_c2d8b_row0_col3, #T_c2d8b_row0_col4 {
#   color: slategrey;
# }
# #T_c2d8b_row2_col2, #T_c2d8b_row4_col2 {
#   color: green;
# }
# #T_c2d8b_row3_col3 {
#   color: magenta;
# }
# </style>
# <table id="T_c2d8b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2d8b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c2d8b_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c2d8b_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c2d8b_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_c2d8b_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2d8b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2d8b_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_c2d8b_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_c2d8b_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_c2d8b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c2d8b_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c2d8b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c2d8b_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_c2d8b_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_c2d8b_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_c2d8b_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_c2d8b_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c2d8b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c2d8b_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_c2d8b_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_c2d8b_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_c2d8b_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_c2d8b_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c2d8b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c2d8b_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_c2d8b_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_c2d8b_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_c2d8b_row3_col3" class="data row3 col3" >M</td>
#       <td id="T_c2d8b_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_c2d8b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c2d8b_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_c2d8b_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_c2d8b_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_c2d8b_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_c2d8b_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(4, 2), (0, 3), (0, 3), (2, 2), (2, 2), (0, 3), (2, 2), (1, 4), (2, 2), (4, 2), (3, 3)]
# Rewards per timestep: [0.3, 0.3, -1, 0.2, -1, -1, -1, -1, -1, -1, -1]
# --------------------------------------------------
# Episode 500 | Timesteps: 2
# Score: -1.15 | Win Rate: 3.00% | Epsilon: 0.1834
# <style type="text/css">
# #T_6c8ce_row0_col0, #T_6c8ce_row0_col1, #T_6c8ce_row0_col2, #T_6c8ce_row0_col3, #T_6c8ce_row1_col0, #T_6c8ce_row1_col1, #T_6c8ce_row1_col2, #T_6c8ce_row1_col3, #T_6c8ce_row2_col0, #T_6c8ce_row2_col1, #T_6c8ce_row2_col2, #T_6c8ce_row2_col3, #T_6c8ce_row2_col4, #T_6c8ce_row3_col0, #T_6c8ce_row3_col1, #T_6c8ce_row3_col2, #T_6c8ce_row3_col3, #T_6c8ce_row3_col4, #T_6c8ce_row4_col0, #T_6c8ce_row4_col1, #T_6c8ce_row4_col2, #T_6c8ce_row4_col3, #T_6c8ce_row4_col4 {
#   color: white;
# }
# #T_6c8ce_row0_col4 {
#   color: green;
# }
# #T_6c8ce_row1_col4 {
#   color: magenta;
# }
# </style>
# <table id="T_6c8ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c8ce_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6c8ce_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6c8ce_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_6c8ce_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_6c8ce_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c8ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c8ce_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_6c8ce_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_6c8ce_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_6c8ce_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_6c8ce_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6c8ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c8ce_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_6c8ce_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_6c8ce_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_6c8ce_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_6c8ce_row1_col4" class="data row1 col4" >M</td>
#     </tr>
#     <tr>
#       <th id="T_6c8ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c8ce_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_6c8ce_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_6c8ce_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_6c8ce_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_6c8ce_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_6c8ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c8ce_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_6c8ce_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_6c8ce_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_6c8ce_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_6c8ce_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_6c8ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c8ce_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_6c8ce_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_6c8ce_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_6c8ce_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_6c8ce_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(0, 4), (1, 4)]
# Rewards per timestep: [0.3, -1]
# --------------------------------------------------
# Episode 600 | Timesteps: 12
# Score: -2.35 | Win Rate: 1.00% | Epsilon: 0.1501
# <style type="text/css">
# #T_97ed7_row0_col0, #T_97ed7_row0_col1, #T_97ed7_row0_col2, #T_97ed7_row1_col0, #T_97ed7_row1_col1, #T_97ed7_row1_col2 {
#   color: slategrey;
# }
# #T_97ed7_row0_col3, #T_97ed7_row1_col3, #T_97ed7_row2_col0, #T_97ed7_row2_col1, #T_97ed7_row2_col2, #T_97ed7_row4_col0 {
#   color: blue;
# }
# #T_97ed7_row0_col4, #T_97ed7_row2_col4, #T_97ed7_row3_col0, #T_97ed7_row3_col1, #T_97ed7_row3_col3, #T_97ed7_row4_col1, #T_97ed7_row4_col2, #T_97ed7_row4_col3, #T_97ed7_row4_col4 {
#   color: white;
# }
# #T_97ed7_row1_col4 {
#   color: magenta;
# }
# #T_97ed7_row2_col3, #T_97ed7_row3_col2, #T_97ed7_row3_col4 {
#   color: green;
# }
# </style>
# <table id="T_97ed7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97ed7_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_97ed7_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_97ed7_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_97ed7_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_97ed7_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97ed7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97ed7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_97ed7_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_97ed7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_97ed7_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_97ed7_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_97ed7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97ed7_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_97ed7_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_97ed7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_97ed7_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_97ed7_row1_col4" class="data row1 col4" >M</td>
#     </tr>
#     <tr>
#       <th id="T_97ed7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97ed7_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_97ed7_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_97ed7_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_97ed7_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_97ed7_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_97ed7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97ed7_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_97ed7_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_97ed7_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_97ed7_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_97ed7_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_97ed7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97ed7_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_97ed7_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_97ed7_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_97ed7_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_97ed7_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(0, 1), (0, 1), (0, 1), (0, 1), (0, 2), (3, 2), (3, 4), (2, 1), (2, 1), (2, 0), (4, 0), (1, 4)]
# Rewards per timestep: [0.3, -1, -1, -1, -1, 0.2, 0.2, -1, -1, -1, 0.3, -1]
# --------------------------------------------------
# Episode 700 | Timesteps: 5
# Score: -2.90 | Win Rate: 2.00% | Epsilon: 0.1229
# <style type="text/css">
# #T_f59c4_row0_col0, #T_f59c4_row0_col1, #T_f59c4_row1_col0, #T_f59c4_row1_col1, #T_f59c4_row2_col0, #T_f59c4_row2_col1, #T_f59c4_row3_col0, #T_f59c4_row4_col0 {
#   color: slategrey;
# }
# #T_f59c4_row0_col2, #T_f59c4_row1_col2, #T_f59c4_row3_col1, #T_f59c4_row4_col1 {
#   color: blue;
# }
# #T_f59c4_row0_col3, #T_f59c4_row0_col4, #T_f59c4_row1_col4, #T_f59c4_row2_col3, #T_f59c4_row2_col4, #T_f59c4_row3_col3, #T_f59c4_row3_col4, #T_f59c4_row4_col2, #T_f59c4_row4_col3, #T_f59c4_row4_col4 {
#   color: white;
# }
# #T_f59c4_row1_col3 {
#   color: magenta;
# }
# #T_f59c4_row2_col2, #T_f59c4_row3_col2 {
#   color: green;
# }
# </style>
# <table id="T_f59c4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f59c4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f59c4_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f59c4_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f59c4_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f59c4_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f59c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f59c4_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f59c4_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f59c4_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_f59c4_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_f59c4_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_f59c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f59c4_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_f59c4_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_f59c4_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_f59c4_row1_col3" class="data row1 col3" >M</td>
#       <td id="T_f59c4_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_f59c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f59c4_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_f59c4_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_f59c4_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_f59c4_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_f59c4_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_f59c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f59c4_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_f59c4_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_f59c4_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_f59c4_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_f59c4_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_f59c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f59c4_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_f59c4_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_f59c4_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_f59c4_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_f59c4_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(3, 0), (3, 0), (3, 0), (0, 0), (1, 3)]
# Rewards per timestep: [0.3, -1, -1, -1, -1]
# --------------------------------------------------
# Episode 800 | Timesteps: 8
# Score: -3.40 | Win Rate: 1.00% | Epsilon: 0.1006
# <style type="text/css">
# #T_46638_row0_col0, #T_46638_row0_col1, #T_46638_row0_col2, #T_46638_row0_col3, #T_46638_row0_col4, #T_46638_row1_col2, #T_46638_row1_col4, #T_46638_row2_col2, #T_46638_row2_col4, #T_46638_row3_col3, #T_46638_row4_col3, #T_46638_row4_col4 {
#   color: white;
# }
# #T_46638_row1_col0, #T_46638_row3_col1, #T_46638_row4_col2 {
#   color: blue;
# }
# #T_46638_row1_col1, #T_46638_row1_col3, #T_46638_row3_col2 {
#   color: red;
# }
# #T_46638_row2_col0, #T_46638_row3_col0, #T_46638_row4_col0, #T_46638_row4_col1 {
#   color: slategrey;
# }
# #T_46638_row2_col1, #T_46638_row3_col4 {
#   color: green;
# }
# #T_46638_row2_col3 {
#   color: magenta;
# }
# </style>
# <table id="T_46638" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46638_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_46638_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_46638_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_46638_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_46638_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46638_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46638_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_46638_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_46638_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_46638_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_46638_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_46638_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46638_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_46638_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_46638_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_46638_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_46638_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_46638_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46638_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_46638_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_46638_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_46638_row2_col3" class="data row2 col3" >M</td>
#       <td id="T_46638_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_46638_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46638_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_46638_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_46638_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_46638_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_46638_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_46638_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46638_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_46638_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_46638_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_46638_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_46638_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(4, 0), (3, 4), (3, 4), (3, 0), (3, 4), (3, 4), (1, 3), (2, 3)]
# Rewards per timestep: [0.3, 0.3, -1, -1, -1, -1, 0.3, -1]
# --------------------------------------------------
# Episode 900 | Timesteps: 2
# Score: -2.25 | Win Rate: 3.00% | Epsilon: 0.0823
# <style type="text/css">
# #T_38477_row0_col0, #T_38477_row0_col1, #T_38477_row0_col2, #T_38477_row0_col3, #T_38477_row0_col4, #T_38477_row1_col0, #T_38477_row1_col1, #T_38477_row1_col3, #T_38477_row1_col4, #T_38477_row2_col0, #T_38477_row2_col1, #T_38477_row2_col2, #T_38477_row2_col3, #T_38477_row2_col4, #T_38477_row3_col0, #T_38477_row3_col2, #T_38477_row3_col3, #T_38477_row3_col4, #T_38477_row4_col0, #T_38477_row4_col1, #T_38477_row4_col2, #T_38477_row4_col3, #T_38477_row4_col4 {
#   color: white;
# }
# #T_38477_row1_col2 {
#   color: green;
# }
# #T_38477_row3_col1 {
#   color: magenta;
# }
# </style>
# <table id="T_38477" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38477_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_38477_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_38477_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_38477_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_38477_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38477_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38477_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_38477_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_38477_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_38477_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_38477_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_38477_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38477_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_38477_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_38477_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_38477_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_38477_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_38477_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38477_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_38477_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_38477_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_38477_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_38477_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_38477_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38477_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_38477_row3_col1" class="data row3 col1" >M</td>
#       <td id="T_38477_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_38477_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_38477_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_38477_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38477_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_38477_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_38477_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_38477_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_38477_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(1, 2), (3, 1)]
# Rewards per timestep: [0.3, -1]
# --------------------------------------------------
# Episode 1000 | Timesteps: 9
# Score: -2.40 | Win Rate: 0.00% | Epsilon: 0.0674
# <style type="text/css">
# #T_ed999_row0_col0 {
#   color: magenta;
# }
# #T_ed999_row0_col1, #T_ed999_row0_col2, #T_ed999_row1_col0, #T_ed999_row1_col2, #T_ed999_row2_col0, #T_ed999_row2_col1, #T_ed999_row2_col2, #T_ed999_row3_col0, #T_ed999_row3_col1, #T_ed999_row3_col2, #T_ed999_row4_col0, #T_ed999_row4_col1, #T_ed999_row4_col2, #T_ed999_row4_col3, #T_ed999_row4_col4 {
#   color: white;
# }
# #T_ed999_row0_col3, #T_ed999_row1_col3, #T_ed999_row3_col4 {
#   color: blue;
# }
# #T_ed999_row0_col4, #T_ed999_row1_col4, #T_ed999_row2_col4 {
#   color: slategrey;
# }
# #T_ed999_row1_col1 {
#   color: red;
# }
# #T_ed999_row2_col3, #T_ed999_row3_col3 {
#   color: green;
# }
# </style>
# <table id="T_ed999" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed999_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ed999_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ed999_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_ed999_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_ed999_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed999_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed999_row0_col0" class="data row0 col0" >M</td>
#       <td id="T_ed999_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_ed999_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_ed999_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_ed999_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed999_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed999_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_ed999_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_ed999_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_ed999_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_ed999_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed999_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed999_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_ed999_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_ed999_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_ed999_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_ed999_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed999_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed999_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_ed999_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_ed999_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_ed999_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_ed999_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ed999_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed999_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_ed999_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_ed999_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_ed999_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_ed999_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(1, 1), (0, 4), (0, 4), (0, 4), (0, 3), (0, 4), (0, 4), (0, 4), (0, 0)]
# Rewards per timestep: [0.3, 0.3, -1, -1, -1, -1, -1, -1, -1]
# --------------------------------------------------
# Episode 1100 | Timesteps: 15
# Score: -2.05 | Win Rate: 0.00% | Epsilon: 0.0552
# <style type="text/css">
# #T_497ad_row0_col0, #T_497ad_row0_col1, #T_497ad_row0_col2, #T_497ad_row1_col0, #T_497ad_row1_col1, #T_497ad_row1_col2, #T_497ad_row2_col0, #T_497ad_row2_col1 {
#   color: slategrey;
# }
# #T_497ad_row0_col3, #T_497ad_row1_col3, #T_497ad_row2_col2, #T_497ad_row2_col3, #T_497ad_row3_col0, #T_497ad_row3_col1 {
#   color: blue;
# }
# #T_497ad_row0_col4, #T_497ad_row1_col4, #T_497ad_row2_col4, #T_497ad_row3_col3, #T_497ad_row4_col0, #T_497ad_row4_col1, #T_497ad_row4_col2, #T_497ad_row4_col3 {
#   color: white;
# }
# #T_497ad_row3_col2 {
#   color: green;
# }
# #T_497ad_row3_col4 {
#   color: red;
# }
# #T_497ad_row4_col4 {
#   color: magenta;
# }
# </style>
# <table id="T_497ad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_497ad_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_497ad_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_497ad_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_497ad_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_497ad_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_497ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_497ad_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_497ad_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_497ad_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_497ad_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_497ad_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_497ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_497ad_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_497ad_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_497ad_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_497ad_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_497ad_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_497ad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_497ad_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_497ad_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_497ad_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_497ad_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_497ad_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_497ad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_497ad_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_497ad_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_497ad_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_497ad_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_497ad_row3_col4" class="data row3 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_497ad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_497ad_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_497ad_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_497ad_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_497ad_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_497ad_row4_col4" class="data row4 col4" >M</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(2, 3), (2, 3), (2, 2), (0, 2), (2, 3), (0, 1), (1, 2), (1, 2), (1, 2), (2, 2), (1, 2), (3, 4), (1, 2), (1, 2), (4, 4)]
# Rewards per timestep: [0.3, -1, 0.2, 0.3, -1, -1, -1, -1, -1, -1, -1, 0.2, -1, -1, -1]
# --------------------------------------------------
# Episode 1200 | Timesteps: 21
# Score: -1.80 | Win Rate: 0.00% | Epsilon: 0.0452
# <style type="text/css">
# #T_0c898_row0_col0, #T_0c898_row0_col3, #T_0c898_row1_col0, #T_0c898_row1_col3, #T_0c898_row2_col4, #T_0c898_row4_col0 {
#   color: blue;
# }
# #T_0c898_row0_col1, #T_0c898_row1_col1, #T_0c898_row1_col2, #T_0c898_row2_col1, #T_0c898_row2_col2, #T_0c898_row3_col0, #T_0c898_row3_col2, #T_0c898_row3_col3, #T_0c898_row3_col4, #T_0c898_row4_col1, #T_0c898_row4_col3, #T_0c898_row4_col4 {
#   color: white;
# }
# #T_0c898_row0_col2, #T_0c898_row2_col0, #T_0c898_row2_col3, #T_0c898_row3_col1 {
#   color: green;
# }
# #T_0c898_row0_col4, #T_0c898_row1_col4 {
#   color: slategrey;
# }
# #T_0c898_row4_col2 {
#   color: magenta;
# }
# </style>
# <table id="T_0c898" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c898_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_0c898_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_0c898_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_0c898_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_0c898_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c898_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c898_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0c898_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_0c898_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_0c898_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_0c898_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0c898_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c898_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_0c898_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_0c898_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_0c898_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_0c898_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0c898_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c898_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_0c898_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_0c898_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_0c898_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_0c898_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0c898_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c898_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_0c898_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_0c898_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_0c898_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_0c898_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_0c898_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c898_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_0c898_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_0c898_row4_col2" class="data row4 col2" >M</td>
#       <td id="T_0c898_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_0c898_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(0, 0), (2, 0), (1, 0), (0, 4), (2, 0), (2, 0), (3, 1), (3, 1), (3, 1), (1, 0), (3, 1), (4, 0), (3, 1), (3, 1), (0, 2), (3, 1), (3, 1), (3, 1), (3, 1), (2, 0), (4, 2)]
# Rewards per timestep: [0.3, 0.3, 0.2, 0.3, -1, -1, 0.2, -1, -1, -1, -1, 0.2, -1, -1, 0.2, -1, -1, -1, -1, -1, -1]
# --------------------------------------------------
# Episode 1300 | Timesteps: 5
# Score: -1.70 | Win Rate: 0.00% | Epsilon: 0.0370
# <style type="text/css">
# #T_fd261_row0_col0, #T_fd261_row0_col1, #T_fd261_row0_col2, #T_fd261_row1_col0, #T_fd261_row1_col1, #T_fd261_row1_col2, #T_fd261_row2_col0, #T_fd261_row2_col1, #T_fd261_row3_col0, #T_fd261_row3_col1, #T_fd261_row3_col2, #T_fd261_row4_col0, #T_fd261_row4_col1, #T_fd261_row4_col2 {
#   color: white;
# }
# #T_fd261_row0_col3, #T_fd261_row4_col3 {
#   color: blue;
# }
# #T_fd261_row0_col4, #T_fd261_row1_col4, #T_fd261_row2_col4, #T_fd261_row3_col4, #T_fd261_row4_col4 {
#   color: slategrey;
# }
# #T_fd261_row1_col3, #T_fd261_row2_col3, #T_fd261_row3_col3 {
#   color: green;
# }
# #T_fd261_row2_col2 {
#   color: magenta;
# }
# </style>
# <table id="T_fd261" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd261_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_fd261_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_fd261_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_fd261_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_fd261_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd261_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd261_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_fd261_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_fd261_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_fd261_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_fd261_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fd261_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd261_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_fd261_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_fd261_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_fd261_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_fd261_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fd261_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd261_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_fd261_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_fd261_row2_col2" class="data row2 col2" >M</td>
#       <td id="T_fd261_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_fd261_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fd261_level0_row3" class="row_heading level0 row3" >3</th>
# ...
#       <td id="T_2264a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2264a_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2264a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2264a_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_2264a_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_2264a_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_2264a_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_2264a_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2264a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2264a_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_2264a_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_2264a_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_2264a_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_2264a_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_2264a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2264a_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_2264a_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_2264a_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_2264a_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_2264a_row3_col4" class="data row3 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2264a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2264a_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_2264a_row4_col1" class="data row4 col1" >M</td>
#       <td id="T_2264a_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_2264a_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_2264a_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(3, 4), (3, 3), (0, 0), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 0), (4, 0), (1, 3), (3, 3), (0, 4), (3, 3), (3, 3), (4, 1)]
# Rewards per timestep: [0.3, 0.2, 0.3, -1, -1, -1, -1, -1, -1, 0.2, 0.2, -1, -1, -1, -1, -1, -1]
# --------------------------------------------------
# Episode 2600 | Timesteps: 5
# Score: -2.70 | Win Rate: 1.00% | Epsilon: 0.0100
# <style type="text/css">
# #T_f6de4_row0_col0, #T_f6de4_row0_col3, #T_f6de4_row0_col4, #T_f6de4_row1_col0, #T_f6de4_row1_col2, #T_f6de4_row1_col3, #T_f6de4_row1_col4, #T_f6de4_row2_col0, #T_f6de4_row2_col1, #T_f6de4_row2_col2, #T_f6de4_row2_col3, #T_f6de4_row2_col4, #T_f6de4_row3_col0, #T_f6de4_row3_col2, #T_f6de4_row3_col3, #T_f6de4_row3_col4, #T_f6de4_row4_col0, #T_f6de4_row4_col1, #T_f6de4_row4_col2, #T_f6de4_row4_col3, #T_f6de4_row4_col4 {
#   color: white;
# }
# #T_f6de4_row0_col1, #T_f6de4_row1_col1 {
#   color: green;
# }
# #T_f6de4_row0_col2 {
#   color: magenta;
# }
# #T_f6de4_row3_col1 {
#   color: blue;
# }
# </style>
# <table id="T_f6de4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6de4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f6de4_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f6de4_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f6de4_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f6de4_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6de4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6de4_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_f6de4_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_f6de4_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_f6de4_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_f6de4_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_f6de4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6de4_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_f6de4_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_f6de4_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_f6de4_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_f6de4_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_f6de4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6de4_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_f6de4_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_f6de4_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_f6de4_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_f6de4_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_f6de4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6de4_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_f6de4_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_f6de4_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_f6de4_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_f6de4_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_f6de4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f6de4_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_f6de4_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_f6de4_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_f6de4_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_f6de4_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(0, 1), (0, 1), (1, 1), (3, 1), (0, 2)]
# Rewards per timestep: [0.3, -1, 0.2, 0.3, -1]
# --------------------------------------------------
# Episode 2700 | Timesteps: 2
# Score: -2.35 | Win Rate: 1.00% | Epsilon: 0.0100
# <style type="text/css">
# #T_189d9_row0_col0, #T_189d9_row0_col1, #T_189d9_row0_col2, #T_189d9_row0_col3, #T_189d9_row0_col4, #T_189d9_row1_col0, #T_189d9_row1_col1, #T_189d9_row1_col2, #T_189d9_row1_col3, #T_189d9_row1_col4, #T_189d9_row2_col1, #T_189d9_row2_col2, #T_189d9_row2_col4, #T_189d9_row3_col0, #T_189d9_row3_col1, #T_189d9_row3_col2, #T_189d9_row3_col3, #T_189d9_row3_col4, #T_189d9_row4_col0, #T_189d9_row4_col1, #T_189d9_row4_col2, #T_189d9_row4_col3, #T_189d9_row4_col4 {
#   color: white;
# }
# #T_189d9_row2_col0 {
#   color: magenta;
# }
# #T_189d9_row2_col3 {
#   color: green;
# }
# </style>
# <table id="T_189d9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_189d9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_189d9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_189d9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_189d9_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_189d9_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_189d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_189d9_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_189d9_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_189d9_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_189d9_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_189d9_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_189d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_189d9_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_189d9_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_189d9_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_189d9_row1_col3" class="data row1 col3" >.</td>
#       <td id="T_189d9_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_189d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_189d9_row2_col0" class="data row2 col0" >M</td>
#       <td id="T_189d9_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_189d9_row2_col2" class="data row2 col2" >.</td>
#       <td id="T_189d9_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_189d9_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_189d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_189d9_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_189d9_row3_col1" class="data row3 col1" >.</td>
#       <td id="T_189d9_row3_col2" class="data row3 col2" >.</td>
#       <td id="T_189d9_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_189d9_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_189d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_189d9_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_189d9_row4_col1" class="data row4 col1" >.</td>
#       <td id="T_189d9_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_189d9_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_189d9_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(2, 3), (2, 0)]
# Rewards per timestep: [0.3, -1]
# --------------------------------------------------
# Episode 2800 | Timesteps: 13
# Score: -4.45 | Win Rate: 0.00% | Epsilon: 0.0100
# <style type="text/css">
# #T_b3284_row0_col0, #T_b3284_row0_col2, #T_b3284_row1_col0, #T_b3284_row1_col1, #T_b3284_row2_col0, #T_b3284_row3_col0, #T_b3284_row4_col0 {
#   color: white;
# }
# #T_b3284_row0_col1, #T_b3284_row2_col1 {
#   color: red;
# }
# #T_b3284_row0_col3, #T_b3284_row1_col3, #T_b3284_row2_col3 {
#   color: blue;
# }
# #T_b3284_row0_col4, #T_b3284_row1_col4, #T_b3284_row2_col4, #T_b3284_row3_col2, #T_b3284_row3_col3, #T_b3284_row3_col4, #T_b3284_row4_col2, #T_b3284_row4_col3, #T_b3284_row4_col4 {
#   color: slategrey;
# }
# #T_b3284_row1_col2 {
#   color: magenta;
# }
# #T_b3284_row2_col2, #T_b3284_row3_col1, #T_b3284_row4_col1 {
#   color: green;
# }
# </style>
# <table id="T_b3284" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3284_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b3284_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b3284_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b3284_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_b3284_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3284_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3284_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_b3284_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_b3284_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_b3284_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_b3284_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b3284_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3284_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_b3284_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_b3284_row1_col2" class="data row1 col2" >M</td>
#       <td id="T_b3284_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_b3284_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b3284_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3284_row2_col0" class="data row2 col0" >.</td>
#       <td id="T_b3284_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_b3284_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_b3284_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_b3284_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b3284_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3284_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_b3284_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_b3284_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_b3284_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_b3284_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b3284_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3284_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_b3284_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_b3284_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_b3284_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_b3284_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(3, 4), (3, 2), (3, 2), (3, 2), (4, 2), (3, 2), (4, 1), (4, 2), (3, 2), (0, 1), (4, 4), (0, 3), (1, 2)]
# Rewards per timestep: [0.3, -1, -1, -1, -1, -1, -1, -1, -1, 0.3, -1, -1, -1]
# --------------------------------------------------
# Episode 2900 | Timesteps: 8
# Score: -2.40 | Win Rate: 1.00% | Epsilon: 0.0100
# <style type="text/css">
# #T_2bee3_row0_col0, #T_2bee3_row0_col1, #T_2bee3_row0_col2, #T_2bee3_row0_col3, #T_2bee3_row0_col4, #T_2bee3_row1_col0, #T_2bee3_row1_col1, #T_2bee3_row1_col2, #T_2bee3_row1_col4, #T_2bee3_row2_col1, #T_2bee3_row2_col3, #T_2bee3_row2_col4, #T_2bee3_row3_col3, #T_2bee3_row3_col4, #T_2bee3_row4_col0, #T_2bee3_row4_col2, #T_2bee3_row4_col3, #T_2bee3_row4_col4 {
#   color: white;
# }
# #T_2bee3_row1_col3 {
#   color: magenta;
# }
# #T_2bee3_row2_col0, #T_2bee3_row3_col0, #T_2bee3_row3_col1, #T_2bee3_row3_col2, #T_2bee3_row4_col1 {
#   color: blue;
# }
# #T_2bee3_row2_col2 {
#   color: red;
# }
# </style>
# <table id="T_2bee3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bee3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2bee3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2bee3_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2bee3_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_2bee3_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bee3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bee3_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_2bee3_row0_col1" class="data row0 col1" >.</td>
#       <td id="T_2bee3_row0_col2" class="data row0 col2" >.</td>
#       <td id="T_2bee3_row0_col3" class="data row0 col3" >.</td>
#       <td id="T_2bee3_row0_col4" class="data row0 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_2bee3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2bee3_row1_col0" class="data row1 col0" >.</td>
#       <td id="T_2bee3_row1_col1" class="data row1 col1" >.</td>
#       <td id="T_2bee3_row1_col2" class="data row1 col2" >.</td>
#       <td id="T_2bee3_row1_col3" class="data row1 col3" >M</td>
#       <td id="T_2bee3_row1_col4" class="data row1 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_2bee3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2bee3_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_2bee3_row2_col1" class="data row2 col1" >.</td>
#       <td id="T_2bee3_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_2bee3_row2_col3" class="data row2 col3" >.</td>
#       <td id="T_2bee3_row2_col4" class="data row2 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_2bee3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2bee3_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_2bee3_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_2bee3_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_2bee3_row3_col3" class="data row3 col3" >.</td>
#       <td id="T_2bee3_row3_col4" class="data row3 col4" >.</td>
#     </tr>
#     <tr>
#       <th id="T_2bee3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2bee3_row4_col0" class="data row4 col0" >.</td>
#       <td id="T_2bee3_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_2bee3_row4_col2" class="data row4 col2" >.</td>
#       <td id="T_2bee3_row4_col3" class="data row4 col3" >.</td>
#       <td id="T_2bee3_row4_col4" class="data row4 col4" >.</td>
#     </tr>
#   </tbody>
# </table>
#
# Actions taken: [(3, 2), (3, 2), (2, 2), (3, 0), (2, 0), (3, 1), (4, 1), (1, 3)]
# Rewards per timestep: [0.3, -1, 0.2, 0.3, 0.2, 0.2, 0.2, -1]
# --------------------------------------------------

# %% [markdown]
# ## 과제
# 1. 완성해오기(설명가능한 상태로 ipynb 파일 구성)
# 2. 알파제로 구조 공부해오기(전원)
# 3. 자기 코드 규칙 정리해오기
